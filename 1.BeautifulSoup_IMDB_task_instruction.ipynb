# %% [markdown]
# ## Introduction and installing the required packages

# %% [markdown]
# The purpose of this exercise is to scrape a IMDB website to find the  following:
# - title,
# - year of release,
# - imdb rating,
# - metascore
# - Number of votes.
#
# The final output will be stored in a pandas dataFrame and for this exercise, you will need to practice looking at the source code of webpages to identify in which tags the inforamtion is held.
# The final output will look like the screen grab below.
#
# Some cells will have screenshots and some cells will have prompts for you to copy the relevant code.

# %% [markdown]
# ![dataframe.png](attachment:dataframe.png)

# %% [markdown]
# It is key that you spend some time working out which tags hold which of the items that you want to collect the data.
# A lot of the data may be embedded within multiple tags, so need to be careful of that.

# %% [markdown]
# ![02_inspect_a_page.png](attachment:02_inspect_a_page.png)

# %% [markdown]
# ![3%20_one_container.jpg](attachment:3%20_one_container.jpg)

# %% [markdown]
# ![8_example.png](attachment:8_example.png)

# %% [markdown]
#  As can be seen in the cell above, the highlighted points is the information that we want to scrape and later place in a data frame.
# - Title
# - Year
# - IMDB rating
# - Metascore
# - Number of votes

# %% [markdown]
# ![01_getrequest.png](attachment:01_getrequest.png)

# %%
#type above code to request the page and print the first 500 characters of the webpage.
#add a line in to check the request has been successful

# %% [markdown]
# ![05_beautifulSoupimport.png](attachment:05_beautifulSoupimport.png)

# %%
#type the above code to import the Beautiful Soup pacakge and create an object to parse the text.
#HTML-parser is being used here, but you can BS comes with three parsers which could be experimented with

# %% [markdown]
# Before extracting the 50 div containers, we need to figure out what distinguishes them from other div elements on that page. Often, the distinctive mark resides in the class attribute. If you inspect the HTML lines of the containers of interest, you’ll notice that the class attribute has two values: lister-item and mode-advanced. This combination is unique to these div containers. We can see that’s true by doing a quick search (Ctrl + F). We have 50 such containers, so we expect to see only 50 matches:

# %% [markdown]
# ![6-image.jpg](attachment:6-image.jpg)

# %% [markdown]
# ![07_getting50.png](attachment:07_getting50.png)

# %%
#type the above code into the get all of the items that have the class_ = 'lister-item mode-advanced'
#print(type and len ) to check what has been requested.

# %% [markdown]
# ![9-image.jpg](attachment:9-image.jpg)

# %% [markdown]
# this shows exactly where the tags for the title can be found

# %% [markdown]
# ## Finding the title location

# %% [markdown]
# ![10_a.png](attachment:10_a.png)

# %%
# type above code

# %% [markdown]
# To get to the code, you will need to access the element by going through nested tags to isolate the information that is required.

# %% [markdown]
# ![11_firstmovie.png](attachment:11_firstmovie.png)

# %%
#typing the above code will return the following. Frim this and the cell above, can work out what is need to print("Logan")?

# %% [markdown]
# ![12_pic.png](attachment:12_pic.png)

# %% [markdown]
# ![14_image.png](attachment:14_image.png)

# %%
#type the above code to get just the title.

# %% [markdown]
# ## Finding the year location

# %% [markdown]
# ![year_location.png](attachment:year_location.png)

# %% [markdown]
# As can be seen, the year is held in the second span . To find that the correct tags need to be identified.

# %% [markdown]
# ![15_image.png](attachment:15_image.png)

# %%
#type the above code to isolate the span class_ within the h3 tag.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#type the above code to get the text only from the selection.

# %% [markdown]
# ## Finding the IMDB rating

# %% [markdown]
# ![imdb_rating.png](attachment:imdb_rating.png)

# %% [markdown]
# Using strong will hopefully isolate the rating.

# %% [markdown]
# ![17_strong.png](attachment:17_strong.png)

# %%
#type the above code in to isolate the score.

# %% [markdown]
# ![18_pic.png](attachment:18_pic.png)

# %%
#type the above code to convert the string to a float and store as first_imdb

# %% [markdown]
# ## Finding the Metascore location

# %% [markdown]
# The screenshot below will help you to isolate the metascore.

# %% [markdown]
# ![metascore.png](attachment:metascore.png)

# %% [markdown]
# ![19_image.png](attachment:19_image.png)

# %%
#type the above code to find the mscore(metascore)
data:image/png;base64,...

# %% [markdown]
# ## Finding the metascore location

# %% [markdown]
# ![nr_votes.png](attachment:nr_votes.png)

# %% [markdown]
# The name attribute is different from the class attribute. Using BeautifulSoup we can access elements by any attribute. The find() and find_all() functions have a parameter named attrs. To this we can pass in the attributes and values we are searching for as a dictionary:

# %% [markdown]
# ![20_span.png](attachment:20_span.png)

# %%
# type the above code to isolate the votes

# %% [markdown]
# You can treat a Tag object just like a dictionary. The HTML attributes are the dictionary’s keys. The values of the HTML attributes are the values of the dictionary’s keys. This is how we can access the value of the data-value attribute:

# %% [markdown]
# ## Putting the lists together

# %% [markdown]
# Now that you have found all of the tags to isolate the individual elements, you can put it all together and collect all of the films on the page.

# %% [markdown]
# ![21_lists.png](attachment:21_lists.png)

# %%
#Type in the above code to create a list

# %% [markdown]
# ![containerloop.png](attachment:containerloop.png)

# %%
#type the above code in collect all of the film information.

# %% [markdown]
# ![pandas.png](attachment:pandas.png)

# %%
#run the code in the above cell to turn into a pandas dataframe and find the information about it.
